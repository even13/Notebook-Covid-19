# %%
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('COVID-19-geographic-disbtribution-worldwide.csv', index_col=0)

# %%
df
# Out:
#             day  month  year  cases  deaths countriesAndTerritories geoId  \
# dateRep
# 10/04/2020   10      4  2020     61       1             Afghanistan    AF
# 09/04/2020    9      4  2020     56       3             Afghanistan    AF
# 08/04/2020    8      4  2020     30       4             Afghanistan    AF
# 07/04/2020    7      4  2020     38       0             Afghanistan    AF
# 06/04/2020    6      4  2020     29       2             Afghanistan    AF
# ...         ...    ...   ...    ...     ...                     ...   ...
# 25/03/2020   25      3  2020      0       0                Zimbabwe    ZW
# 24/03/2020   24      3  2020      0       1                Zimbabwe    ZW
# 23/03/2020   23      3  2020      0       0                Zimbabwe    ZW
# 22/03/2020   22      3  2020      1       0                Zimbabwe    ZW
# 21/03/2020   21      3  2020      1       0                Zimbabwe    ZW
#
#            countryterritoryCode  popData2018
# dateRep
# ...

# %%
subset=df.loc[['10/04/2020'],['countriesAndTerritories', 'cases', 'deaths']]

# %%
subset.head()
# Out:
#            countriesAndTerritories  cases  deaths
# dateRep
# 10/04/2020             Afghanistan     61       1
# 10/04/2020                 Albania      9       1
# 10/04/2020                 Andorra     19       2
# 10/04/2020                 Algeria     94      30
# 10/04/2020                  Angola      0       0

# %%
srtsub=subset.sort_values('cases',ascending=False)

# %%
x=srtsub['countriesAndTerritories'].values.tolist()
#df.loc[['10/04/2020'], ['countriesAndTerritories']]

# %%
y=srtsub['cases'].values.tolist()

# %%
from matplotlib.pyplot import figure
from matplotlib.widgets import Slider, Button, RadioButtons
figure(num=None, figsize=(16, 6), dpi=80, facecolor='w', edgecolor='k')
plt.xticks(rotation=90, fontsize=6)
plt.plot(x,y)
